# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Mahadeshwar/Facial-Recognition/blob/master/NlP_class_3_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import spacy
spacy_nlp = spacy.load('en_core_web_sm')

# %%
data = pd.read_json('http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz', lines=True)

# %%
data = data.head(100)

# %%
 Sentence = data['reviewText'][2]

# %%
doc = spacy_nlp(Sentence)
tokens = [token.text for token in doc]

# %%
lemma = [token.lemma_ for token in doc]

# %%
pos_tag = [token.pos_ for token in doc]

# %%
def spacy_pipe(Sentence):
  doc = spacy_nlp(Sentence)
  tokens = [token.text for token in doc]
  lemma = [token.lemma_ for token in doc]
  pos_tag = [token.pos_ for token in doc]
  spacy_dic = {'tokens':tokens,'Lemmatized Text':lemma,'pos_tagging for each token':pos_tag}
  return spacy_dic

# %%
spacy_pipe(Sentence)
# Out:
# {'Lemmatized Text': ['-PRON-',
#   'have',
#   'an',
#   'hp',
#   '48gx',
#   'that',
#   'have',
#   'be',
#   'kick',
#   'for',
#   'more',
#   'than',
#   'twenty',
#   'year',
#   'and',
#   'an',
#   'HP',
#   '11',
#   'that',
#   'be',
#   'more',
#   'than',
#   '25',
#   'year',
#   'old',
#   'and',
#   'still',
#   'flawless',
#   '.',
#   ' ',
#   '-PRON-',
#   'have',
#   'have',
#   'this',
#   '12c',
#   'for',
#   'about',
#   '18',
#   'month',
#   'and',
#   'the',
#   'number',
#   '5',
#   'key',
#   'be',
#   'already',
#   'give',
#   '-PRON-',
#   'trouble',
#   '(',
#   'have',
#   'to',
#   'press',
#   'hard',
#   'for',
#   '-PRON-',
#   'to',
#   'register',
#   ')',
#   '.',
#   ' ',
#   'no',
#   'drop',
#   ',',
#   'no',
#   'abuse',
#   '.',
#   ' ',
#   'the',
#   'overall',
#   'feel',
#   'of',
#   'this',
#   'new',
#   'HP',
#   'be',
#   'cheap',
#   'plastic',
#   '.',
#   ' ',
#   'the',
#   'key',
#   'feel',
#   'hollow',
#   'and',
# ...

# %%
data['Spacy_Pipe'] = data.reviewText.apply(spacy_pipe)

# %%
data['Spacy_Pipe'][2]
# Out:
# {'Lemmatized Text': ['-PRON-',
#   'have',
#   'an',
#   'hp',
#   '48gx',
#   'that',
#   'have',
#   'be',
#   'kick',
#   'for',
#   'more',
#   'than',
#   'twenty',
#   'year',
#   'and',
#   'an',
#   'HP',
#   '11',
#   'that',
#   'be',
#   'more',
#   'than',
#   '25',
#   'year',
#   'old',
#   'and',
#   'still',
#   'flawless',
#   '.',
#   ' ',
#   '-PRON-',
#   'have',
#   'have',
#   'this',
#   '12c',
#   'for',
#   'about',
#   '18',
#   'month',
#   'and',
#   'the',
#   'number',
#   '5',
#   'key',
#   'be',
#   'already',
#   'give',
#   '-PRON-',
#   'trouble',
#   '(',
#   'have',
#   'to',
#   'press',
#   'hard',
#   'for',
#   '-PRON-',
#   'to',
#   'register',
#   ')',
#   '.',
#   ' ',
#   'no',
#   'drop',
#   ',',
#   'no',
#   'abuse',
#   '.',
#   ' ',
#   'the',
#   'overall',
#   'feel',
#   'of',
#   'this',
#   'new',
#   'HP',
#   'be',
#   'cheap',
#   'plastic',
#   '.',
#   ' ',
#   'the',
#   'key',
#   'feel',
#   'hollow',
#   'and',
# ...
